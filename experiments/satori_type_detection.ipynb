# %%
import numpy as np
import fasttext
from collections import defaultdict
import pickle
import csv
from gensim.models import KeyedVectors
from sklearn.preprocessing import normalize
from lifelong_dnn import LifeLongDNN

# %%
#load pre-trained fasttext vector and also Bing entity data

# fasttext_emb = KeyedVectors.load_word2vec_format('/home/weiwya/lifelong-learning/language_detection/data/wiki-news-300d-1M.vec')
wanted = set(['biology.organism_classification', 'book.written_work', 
          'film.character', 'tv.series_episode', 'organization.organization',
          'film.film','music.group', 'commerce.consumer_product', 'book.book',
          'music.artist','people.person','film.actor','book.edition', 'media_common.actor',
          'book.author','american_football.player','tv.program', 'business.operation',
          'education.field_of_study','education.school'])

stuff = pickle.load(open('/mnt/c/Users/weiwya/Downloads/llf_training_data.pickle', 'rb'))
entities = defaultdict(list)
for item in stuff:
    itype = item[1].split('/')[-1]
    if itype in wanted:
        entities[itype].append(item[-1])
for k, v in entities.items():
    entities[k] = np.array(v).reshape(-1, 300)
    print(k, entities[k].shape)
labels = {t:i for i, t in enumerate(entities.keys())}
idToLabels = {v:k for k, v in labels.items()}
# Out:
# biology.organism_classification (19087, 300)
# book.written_work (66485, 300)
# film.character (15900, 300)
# tv.series_episode (20104, 300)
# organization.organization (54972, 300)
# film.film (52436, 300)
# music.group (11748, 300)
# commerce.consumer_product (12739, 300)
# book.book (44924, 300)
# music.artist (33772, 300)
# people.person (19482, 300)
# film.actor (24186, 300)
# book.edition (13636, 300)
# media_common.actor (21307, 300)
# book.author (19681, 300)
# american_football.player (13008, 300)
# tv.program (17527, 300)
# business.operation (18216, 300)
# education.field_of_study (19200, 300)
# education.school (30247, 300)

# %%
def generate_train_test(entities,tasks, train_size=10000, test_size=1000, ):
    labels = {t:i for i, t in enumerate(entities.keys())}
    idToLabels = {v:k for k, v in labels.items()}
    trains, tests = [], []
    train_labels, test_labels = [], []
    for t in tasks:
        dd = entities[idToLabels[t]]
        if dd.shape[0] < train_size + test_size:
            print('adjusted train_size:')
            train_size = dd.shape[0] - test_size
            print(train_size)
        
        idx = np.random.choice(dd.shape[0], dd.shape[0], replace=False )
        dd = dd[idx]
        train = dd[:train_size]
        test = dd[train_size: train_size + test_size]

        trains.append(train)
        tests.append(test)

        train_labels+=[t]* train_size
        test_labels+= [t]*test_size
    
    #shuffle orders for good meature   
    idx = np.random.choice(len(train_labels), len(train_labels), replace= False)
    trains = np.vstack(trains)[idx]
    train_labels = np.array(train_labels)[idx]
    
    idx = np.random.choice(len(test_labels), len(test_labels), replace=False)
    tests = np.vstack(tests)[idx]
    test_labels = np.array(test_labels)[idx]
    return trains, train_labels, tests, test_labels
  

def get_score(prediction, labels):
    acc = (labels == prediction).sum()/labels.shape[0]
    return acc

# %%
def run_iter(seed, entities, n_tasks=5, task_per_batch = 4,  train_size=10000, test_size = 1000, do_random_task = False):
    #TODO: turn parallel back on once locking due to ram is fixed
    llf = LifeLongDNN(acorn=seed, parallel=False)
    prv_test, prv_labels = {},{}
    np.random.seed(seed)
    efficiency = defaultdict(list)
    batch_idx = np.arange(len(entities)).reshape(n_tasks, task_per_batch)
    forward_acc = {}
    reverse_eff= defaultdict(list)
    forward_eff= {}
    
    for iteration in range(n_tasks):
        if do_random_task:
            cc = np.random.choice(len(entities), task_per_batch, replace=False)
        else:
            cc = batch_idx[iteration%n_tasks]
        print(iteration, cc, [idToLabels[x] for x in cc])

        train, train_labels , test, test_labels = generate_train_test(entities, cc, train_size=train_size, test_size=test_size)        
        prv_test[iteration] = test
        prv_labels[iteration] = test_labels

        llf.new_forest(train, train_labels)
        
        p0 = llf.predict(test, representation=iteration, decider=iteration)  
        p1 = llf.predict(test, representation='all', decider=iteration)
        a0 = get_score(p0, test_labels)
        a1 = get_score(p1, test_labels)
        forward_acc[iteration] = a1
        forward_eff[iteration] = (1-a0) / (1-a1)
        
        
        for j in range(iteration):
            p0 = llf.predict(prv_test[j], representation=j, decider=j)  
            p1 = llf.predict(prv_test[j], representation='all', decider=j)
            e0 = 1 - get_score(p0, prv_labels[j])
            e1 = 1 - get_score(p1, prv_labels[j])
            eff = e0 / e1
            print ('%i, org_error: %s tran_error: %s tran_eff: %s' %(j, e0, e1, eff ))
            reverse_eff[j].append(eff)
        print()
            
    return seed, (forward_acc, forward_eff, reverse_eff)

# %%
#run non-overlapping batches w different random seed
res = []
for i in range(10):
    res.append(run_iter(i*100, entities))
# Out:
# 0 [0 1 2 3] ['biology.organism_classification', 'book.written_work', 'film.character', 'tv.series_episode']
#
# 1 [4 5 6 7] ['organization.organization', 'film.film', 'music.group', 'commerce.consumer_product']
# 0, org_error: 0.4225 tran_error: 0.42500000000000004 tran_eff: 0.9941176470588234
#
# 2 [ 8  9 10 11] ['book.book', 'music.artist', 'people.person', 'film.actor']
# 0, org_error: 0.4225 tran_error: 0.42000000000000004 tran_eff: 1.005952380952381
# 1, org_error: 0.6225 tran_error: 0.6 tran_eff: 1.0375
#
# 3 [12 13 14 15] ['book.edition', 'media_common.actor', 'book.author', 'american_football.player']
# 0, org_error: 0.4225 tran_error: 0.4275 tran_eff: 0.9883040935672515
# 1, org_error: 0.6225 tran_error: 0.595 tran_eff: 1.046218487394958
# 2, org_error: 0.52 tran_error: 0.5175000000000001 tran_eff: 1.004830917874396
#
# 4 [16 17 18 19] ['tv.program', 'business.operation', 'education.field_of_study', 'education.school']
# 0, org_error: 0.4225 tran_error: 0.4375 tran_eff: 0.9657142857142856
# 1, org_error: 0.6225 tran_error: 0.5875 tran_eff: 1.0595744680851065
# 2, org_error: 0.52 tran_error: 0.5075000000000001 tran_eff: 1.024630541871921
# 3, org_error: 0.39249999999999996 tran_error: 0.38 tran_eff: 1.032894736842105
#
# 0 [0 1 2 3] ['biology.organism_classification', 'book.written_work', 'film.character', 'tv.series_episode']
#
# 1 [4 5 6 7] ['organization.organization', 'film.film', 'music.group', 'commerce.consumer_product']
# 0, org_error: 0.4 tran_error: 0.405 tran_eff: 0.9876543209876543
#
# 2 [ 8  9 10 11] ['book.book', 'music.artist', 'people.person', 'film.actor']
# 0, org_error: 0.4 tran_error: 0.38249999999999995 tran_eff: 1.0457516339869284
# 1, org_error: 0.5800000000000001 tran_error: 0.5475 tran_eff: 1.0593607305936075
#
# 3 [12 13 14 15] ['book.edition', 'media_common.actor', 'book.author', 'american_football.player']
# 0, org_error: 0.4 tran_error: 0.36250000000000004 tran_eff: 1.103448275862069
# 1, org_error: 0.5800000000000001 tran_error: 0.5275000000000001 tran_eff: 1.099526066350711
# 2, org_error: 0.46499999999999997 tran_error: 0.46499999999999997 tran_eff: 1.0
#
# 4 [16 17 18 19] ['tv.program', 'business.operation', 'education.field_of_study', 'education.school']
# 0, org_error: 0.4 tran_error: 0.37 tran_eff: 1.0810810810810811
# 1, org_error: 0.5800000000000001 tran_error: 0.5549999999999999 tran_eff: 1.0450450450450453
# 2, org_error: 0.46499999999999997 tran_error: 0.4525 tran_eff: 1.027624309392265
# 3, org_error: 0.47250000000000003 tran_error: 0.4425 tran_eff: 1.0677966101694916
#
# 0 [0 1 2 3] ['biology.organism_classification', 'book.written_work', 'film.character', 'tv.series_episode']
#
# 1 [4 5 6 7] ['organization.organization', 'film.film', 'music.group', 'commerce.consumer_product']
# 0, org_error: 0.38249999999999995 tran_error: 0.38 tran_eff: 1.006578947368421
#
# 2 [ 8  9 10 11] ['book.book', 'music.artist', 'people.person', 'film.actor']
# 0, org_error: 0.38249999999999995 tran_error: 0.37250000000000005 tran_eff: 1.0268456375838924
# 1, org_error: 0.5925 tran_error: 0.595 tran_eff: 0.9957983193277312
#
# 3 [12 13 14 15] ['book.edition', 'media_common.actor', 'book.author', 'american_football.player']
# 0, org_error: 0.38249999999999995 tran_error: 0.385 tran_eff: 0.9935064935064933
# 1, org_error: 0.5925 tran_error: 0.5875 tran_eff: 1.0085106382978724
# 2, org_error: 0.4625 tran_error: 0.43999999999999995 tran_eff: 1.0511363636363638
#
# 4 [16 17 18 19] ['tv.program', 'business.operation', 'education.field_of_study', 'education.school']
# 0, org_error: 0.38249999999999995 tran_error: 0.38749999999999996 tran_eff: 0.9870967741935484
# 1, org_error: 0.5925 tran_error: 0.5974999999999999 tran_eff: 0.9916317991631801
# 2, org_error: 0.4625 tran_error: 0.43500000000000005 tran_eff: 1.0632183908045976
# 3, org_error: 0.4275 tran_error: 0.38249999999999995 tran_eff: 1.1176470588235294
#
# 0 [0 1 2 3] ['biology.organism_classification', 'book.written_work', 'film.character', 'tv.series_episode']
#
# 1 [4 5 6 7] ['organization.organization', 'film.film', 'music.group', 'commerce.consumer_product']
# 0, org_error: 0.4225 tran_error: 0.42000000000000004 tran_eff: 1.005952380952381
#
# 2 [ 8  9 10 11] ['book.book', 'music.artist', 'people.person', 'film.actor']
# 0, org_error: 0.4225 tran_error: 0.41000000000000003 tran_eff: 1.0304878048780486
# 1, org_error: 0.615 tran_error: 0.5900000000000001 tran_eff: 1.042372881355932
#
# 3 [12 13 14 15] ['book.edition', 'media_common.actor', 'book.author', 'american_football.player']
# 0, org_error: 0.4225 tran_error: 0.395 tran_eff: 1.0696202531645569
# 1, org_error: 0.615 tran_error: 0.5925 tran_eff: 1.0379746835443038
# 2, org_error: 0.49 tran_error: 0.4575 tran_eff: 1.07103825136612
#
# 4 [16 17 18 19] ['tv.program', 'business.operation', 'education.field_of_study', 'education.school']
# 0, org_error: 0.4225 tran_error: 0.40249999999999997 tran_eff: 1.049689440993789
# 1, org_error: 0.615 tran_error: 0.5925 tran_eff: 1.0379746835443038
# 2, org_error: 0.49 tran_error: 0.47 tran_eff: 1.0425531914893618
# 3, org_error: 0.4375 tran_error: 0.4 tran_eff: 1.09375
#
# 0 [0 1 2 3] ['biology.organism_classification', 'book.written_work', 'film.character', 'tv.series_episode']
#
# 1 [4 5 6 7] ['organization.organization', 'film.film', 'music.group', 'commerce.consumer_product']
# 0, org_error: 0.395 tran_error: 0.4075 tran_eff: 0.9693251533742332
#
# 2 [ 8  9 10 11] ['book.book', 'music.artist', 'people.person', 'film.actor']
# 0, org_error: 0.395 tran_error: 0.395 tran_eff: 1.0
# 1, org_error: 0.605 tran_error: 0.585 tran_eff: 1.0341880341880343
#
# 3 [12 13 14 15] ['book.edition', 'media_common.actor', 'book.author', 'american_football.player']
# 0, org_error: 0.395 tran_error: 0.39249999999999996 tran_eff: 1.0063694267515926
# 1, org_error: 0.605 tran_error: 0.5825 tran_eff: 1.03862660944206
# 2, org_error: 0.5275000000000001 tran_error: 0.48 tran_eff: 1.0989583333333335
#
# 4 [16 17 18 19] ['tv.program', 'business.operation', 'education.field_of_study', 'education.school']
# 0, org_error: 0.395 tran_error: 0.40249999999999997 tran_eff: 0.9813664596273293
# 1, org_error: 0.605 tran_error: 0.575 tran_eff: 1.0521739130434784
# 2, org_error: 0.5275000000000001 tran_error: 0.48 tran_eff: 1.0989583333333335
# 3, org_error: 0.4275 tran_error: 0.39249999999999996 tran_eff: 1.089171974522293
#
# 0 [0 1 2 3] ['biology.organism_classification', 'book.written_work', 'film.character', 'tv.series_episode']
#
# 1 [4 5 6 7] ['organization.organization', 'film.film', 'music.group', 'commerce.consumer_product']
# 0, org_error: 0.42500000000000004 tran_error: 0.41500000000000004 tran_eff: 1.0240963855421688
#
# 2 [ 8  9 10 11] ['book.book', 'music.artist', 'people.person', 'film.actor']
# 0, org_error: 0.42500000000000004 tran_error: 0.41000000000000003 tran_eff: 1.0365853658536586
# 1, org_error: 0.595 tran_error: 0.5675 tran_eff: 1.0484581497797356
#
# 3 [12 13 14 15] ['book.edition', 'media_common.actor', 'book.author', 'american_football.player']
# 0, org_error: 0.42500000000000004 tran_error: 0.4 tran_eff: 1.0625
# 1, org_error: 0.595 tran_error: 0.5675 tran_eff: 1.0484581497797356
# 2, org_error: 0.49 tran_error: 0.47 tran_eff: 1.0425531914893618
#
# 4 [16 17 18 19] ['tv.program', 'business.operation', 'education.field_of_study', 'education.school']
# 0, org_error: 0.42500000000000004 tran_error: 0.405 tran_eff: 1.0493827160493827
# 1, org_error: 0.595 tran_error: 0.5700000000000001 tran_eff: 1.043859649122807
# 2, org_error: 0.49 tran_error: 0.47 tran_eff: 1.0425531914893618
# 3, org_error: 0.48250000000000004 tran_error: 0.405 tran_eff: 1.191358024691358
#
# 0 [0 1 2 3] ['biology.organism_classification', 'book.written_work', 'film.character', 'tv.series_episode']
#
# 1 [4 5 6 7] ['organization.organization', 'film.film', 'music.group', 'commerce.consumer_product']
# 0, org_error: 0.4075 tran_error: 0.39249999999999996 tran_eff: 1.0382165605095541
#
# 2 [ 8  9 10 11] ['book.book', 'music.artist', 'people.person', 'film.actor']
# 0, org_error: 0.4075 tran_error: 0.4075 tran_eff: 1.0
# 1, org_error: 0.615 tran_error: 0.61 tran_eff: 1.0081967213114753
#
# 3 [12 13 14 15] ['book.edition', 'media_common.actor', 'book.author', 'american_football.player']
# 0, org_error: 0.4075 tran_error: 0.4125 tran_eff: 0.9878787878787879
# 1, org_error: 0.615 tran_error: 0.6025 tran_eff: 1.020746887966805
# 2, org_error: 0.5075000000000001 tran_error: 0.475 tran_eff: 1.0684210526315792
#
# 4 [16 17 18 19] ['tv.program', 'business.operation', 'education.field_of_study', 'education.school']
# 0, org_error: 0.4075 tran_error: 0.41000000000000003 tran_eff: 0.9939024390243901
# 1, org_error: 0.615 tran_error: 0.585 tran_eff: 1.0512820512820513
# 2, org_error: 0.5075000000000001 tran_error: 0.4675 tran_eff: 1.0855614973262033
# 3, org_error: 0.4625 tran_error: 0.42000000000000004 tran_eff: 1.101190476190476
#
# 0 [0 1 2 3] ['biology.organism_classification', 'book.written_work', 'film.character', 'tv.series_episode']
#
# 1 [4 5 6 7] ['organization.organization', 'film.film', 'music.group', 'commerce.consumer_product']
# 0, org_error: 0.38249999999999995 tran_error: 0.36750000000000005 tran_eff: 1.040816326530612
#
# 2 [ 8  9 10 11] ['book.book', 'music.artist', 'people.person', 'film.actor']
# 0, org_error: 0.38249999999999995 tran_error: 0.365 tran_eff: 1.047945205479452
# 1, org_error: 0.5974999999999999 tran_error: 0.625 tran_eff: 0.9559999999999998
#
# 3 [12 13 14 15] ['book.edition', 'media_common.actor', 'book.author', 'american_football.player']
# 0, org_error: 0.38249999999999995 tran_error: 0.36 tran_eff: 1.0625
# 1, org_error: 0.5974999999999999 tran_error: 0.6125 tran_eff: 0.9755102040816325
# 2, org_error: 0.51 tran_error: 0.5025 tran_eff: 1.0149253731343284
#
# 4 [16 17 18 19] ['tv.program', 'business.operation', 'education.field_of_study', 'education.school']
# 0, org_error: 0.38249999999999995 tran_error: 0.36250000000000004 tran_eff: 1.0551724137931031
# 1, org_error: 0.5974999999999999 tran_error: 0.595 tran_eff: 1.004201680672269
# 2, org_error: 0.51 tran_error: 0.51 tran_eff: 1.0
# 3, org_error: 0.47 tran_error: 0.4375 tran_eff: 1.0742857142857143
#
# 0 [0 1 2 3] ['biology.organism_classification', 'book.written_work', 'film.character', 'tv.series_episode']
#
# 1 [4 5 6 7] ['organization.organization', 'film.film', 'music.group', 'commerce.consumer_product']
# 0, org_error: 0.43000000000000005 tran_error: 0.41500000000000004 tran_eff: 1.036144578313253
#
# 2 [ 8  9 10 11] ['book.book', 'music.artist', 'people.person', 'film.actor']
# 0, org_error: 0.43000000000000005 tran_error: 0.405 tran_eff: 1.0617283950617284
# 1, org_error: 0.5974999999999999 tran_error: 0.5625 tran_eff: 1.0622222222222222
#
# 3 [12 13 14 15] ['book.edition', 'media_common.actor', 'book.author', 'american_football.player']
# 0, org_error: 0.43000000000000005 tran_error: 0.39 tran_eff: 1.1025641025641026
# 1, org_error: 0.5974999999999999 tran_error: 0.5775 tran_eff: 1.0346320346320346
# 2, org_error: 0.5025 tran_error: 0.485 tran_eff: 1.036082474226804
#
# 4 [16 17 18 19] ['tv.program', 'business.operation', 'education.field_of_study', 'education.school']
# 0, org_error: 0.43000000000000005 tran_error: 0.395 tran_eff: 1.0886075949367089
# 1, org_error: 0.5974999999999999 tran_error: 0.5900000000000001 tran_eff: 1.0127118644067794
# 2, org_error: 0.5025 tran_error: 0.475 tran_eff: 1.0578947368421052
# 3, org_error: 0.4325 tran_error: 0.43000000000000005 tran_eff: 1.0058139534883719
#
# 0 [0 1 2 3] ['biology.organism_classification', 'book.written_work', 'film.character', 'tv.series_episode']
#
# 1 [4 5 6 7] ['organization.organization', 'film.film', 'music.group', 'commerce.consumer_product']
# 0, org_error: 0.40249999999999997 tran_error: 0.4 tran_eff: 1.0062499999999999
#
# 2 [ 8  9 10 11] ['book.book', 'music.artist', 'people.person', 'film.actor']
# 0, org_error: 0.40249999999999997 tran_error: 0.38249999999999995 tran_eff: 1.0522875816993464
# 1, org_error: 0.63 tran_error: 0.575 tran_eff: 1.0956521739130436
#
# 3 [12 13 14 15] ['book.edition', 'media_common.actor', 'book.author', 'american_football.player']
# 0, org_error: 0.40249999999999997 tran_error: 0.39749999999999996 tran_eff: 1.0125786163522013
# 1, org_error: 0.63 tran_error: 0.5675 tran_eff: 1.1101321585903083
# 2, org_error: 0.485 tran_error: 0.495 tran_eff: 0.9797979797979798
#
# 4 [16 17 18 19] ['tv.program', 'business.operation', 'education.field_of_study', 'education.school']
# 0, org_error: 0.40249999999999997 tran_error: 0.38249999999999995 tran_eff: 1.0522875816993464
# 1, org_error: 0.63 tran_error: 0.55 tran_eff: 1.1454545454545453
# 2, org_error: 0.485 tran_error: 0.5 tran_eff: 0.97
# 3, org_error: 0.4675 tran_error: 0.4275 tran_eff: 1.0935672514619883

# %%
#run overlapping batches w different random seed
res = []
for i in range(10):
    res.append(run_iter(i*100, entities, do_random_task = True ))
# Out:
# 0 [18  1 19  8] ['education.field_of_study', 'book.written_work', 'education.school', 'book.book']
#
# 1 [ 9  8 15  0] ['music.artist', 'book.book', 'american_football.player', 'biology.organism_classification']
# 0, org_error: 0.3225 tran_error: 0.31999999999999995 tran_eff: 1.0078125000000002
#
# 2 [ 0  9 12  2] ['biology.organism_classification', 'music.artist', 'book.edition', 'film.character']
# 0, org_error: 0.3225 tran_error: 0.3075 tran_eff: 1.048780487804878
# 1, org_error: 0.27249999999999996 tran_error: 0.265 tran_eff: 1.0283018867924527
#
# 3 [1 2 0 3] ['book.written_work', 'film.character', 'biology.organism_classification', 'tv.series_episode']
# 0, org_error: 0.3225 tran_error: 0.31000000000000005 tran_eff: 1.040322580645161
# 1, org_error: 0.27249999999999996 tran_error: 0.26249999999999996 tran_eff: 1.0380952380952382
# 2, org_error: 0.4325 tran_error: 0.38 tran_eff: 1.138157894736842
#
# 4 [ 3  0 17 10] ['tv.series_episode', 'biology.organism_classification', 'business.operation', 'people.person']
# 0, org_error: 0.3225 tran_error: 0.31499999999999995 tran_eff: 1.023809523809524
# 1, org_error: 0.27249999999999996 tran_error: 0.26249999999999996 tran_eff: 1.0380952380952382
# 2, org_error: 0.4325 tran_error: 0.37 tran_eff: 1.1689189189189189
# 3, org_error: 0.4425 tran_error: 0.42000000000000004 tran_eff: 1.0535714285714284
#
# 0 [17 19 11 18] ['business.operation', 'education.school', 'film.actor', 'education.field_of_study']
#
# 1 [14 10 19 18] ['book.author', 'people.person', 'education.school', 'education.field_of_study']
# 0, org_error: 0.12250000000000005 tran_error: 0.11250000000000004 tran_eff: 1.088888888888889
#
# 2 [ 5  3 19  1] ['film.film', 'tv.series_episode', 'education.school', 'book.written_work']
# 0, org_error: 0.12250000000000005 tran_error: 0.11499999999999999 tran_eff: 1.0652173913043483
# 1, org_error: 0.21499999999999997 tran_error: 0.19499999999999995 tran_eff: 1.1025641025641026
#
# 3 [13 18 12 14] ['media_common.actor', 'education.field_of_study', 'book.edition', 'book.author']
# 0, org_error: 0.12250000000000005 tran_error: 0.10999999999999999 tran_eff: 1.1136363636363642
# 1, org_error: 0.21499999999999997 tran_error: 0.21250000000000002 tran_eff: 1.0117647058823527
# 2, org_error: 0.47750000000000004 tran_error: 0.48 tran_eff: 0.9947916666666667
#
# 4 [11  5 13 10] ['film.actor', 'film.film', 'media_common.actor', 'people.person']
# 0, org_error: 0.12250000000000005 tran_error: 0.09999999999999998 tran_eff: 1.2250000000000008
# 1, org_error: 0.21499999999999997 tran_error: 0.20750000000000002 tran_eff: 1.0361445783132528
# 2, org_error: 0.47750000000000004 tran_error: 0.48750000000000004 tran_eff: 0.9794871794871794
# 3, org_error: 0.35250000000000004 tran_error: 0.32999999999999996 tran_eff: 1.0681818181818183
#
# 0 [ 2  0 17  5] ['film.character', 'biology.organism_classification', 'business.operation', 'film.film']
#
# 1 [13 16  0  4] ['media_common.actor', 'tv.program', 'biology.organism_classification', 'organization.organization']
# 0, org_error: 0.275 tran_error: 0.23750000000000004 tran_eff: 1.157894736842105
#
# 2 [ 0  5  3 18] ['biology.organism_classification', 'film.film', 'tv.series_episode', 'education.field_of_study']
# 0, org_error: 0.275 tran_error: 0.235 tran_eff: 1.170212765957447
# 1, org_error: 0.1875 tran_error: 0.1775 tran_eff: 1.0563380281690142
#
# 3 [16 10 14  5] ['tv.program', 'people.person', 'book.author', 'film.film']
# 0, org_error: 0.275 tran_error: 0.22750000000000004 tran_eff: 1.2087912087912087
# 1, org_error: 0.1875 tran_error: 0.1725 tran_eff: 1.0869565217391306
# 2, org_error: 0.355 tran_error: 0.32999999999999996 tran_eff: 1.075757575757576
#
# 4 [17 18 12 19] ['business.operation', 'education.field_of_study', 'book.edition', 'education.school']
# 0, org_error: 0.275 tran_error: 0.22750000000000004 tran_eff: 1.2087912087912087
# 1, org_error: 0.1875 tran_error: 0.1775 tran_eff: 1.0563380281690142
# 2, org_error: 0.355 tran_error: 0.33499999999999996 tran_eff: 1.0597014925373134
# 3, org_error: 0.495 tran_error: 0.475 tran_eff: 1.0421052631578949
#
# 0 [18 14  0 12] ['education.field_of_study', 'book.author', 'biology.organism_classification', 'book.edition']
#
# 1 [ 7  1 18  5] ['commerce.consumer_product', 'book.written_work', 'education.field_of_study', 'film.film']
# 0, org_error: 0.19499999999999995 tran_error: 0.1875 tran_eff: 1.0399999999999998
#
# 2 [ 6 13 12  0] ['music.group', 'media_common.actor', 'book.edition', 'biology.organism_classification']
# 0, org_error: 0.19499999999999995 tran_error: 0.1975 tran_eff: 0.9873417721518984
# 1, org_error: 0.5549999999999999 tran_error: 0.5425 tran_eff: 1.023041474654378
#
# 3 [ 5  8 14 10] ['film.film', 'book.book', 'book.author', 'people.person']
# 0, org_error: 0.19499999999999995 tran_error: 0.1975 tran_eff: 0.9873417721518984
# 1, org_error: 0.5549999999999999 tran_error: 0.5425 tran_eff: 1.023041474654378
# 2, org_error: 0.2925 tran_error: 0.26749999999999996 tran_eff: 1.0934579439252337
#
# 4 [13 11  8  4] ['media_common.actor', 'film.actor', 'book.book', 'organization.organization']
# 0, org_error: 0.19499999999999995 tran_error: 0.1875 tran_eff: 1.0399999999999998
# 1, org_error: 0.5549999999999999 tran_error: 0.53 tran_eff: 1.0471698113207546
# 2, org_error: 0.2925 tran_error: 0.2825 tran_eff: 1.0353982300884956
# 3, org_error: 0.5075000000000001 tran_error: 0.47 tran_eff: 1.0797872340425534
#
# 0 [18  0 16  3] ['education.field_of_study', 'biology.organism_classification', 'tv.program', 'tv.series_episode']
#
# 1 [4 5 9 6] ['organization.organization', 'film.film', 'music.artist', 'music.group']
# 0, org_error: 0.3425 tran_error: 0.31499999999999995 tran_eff: 1.0873015873015877
#
# 2 [ 3 16  2 13] ['tv.series_episode', 'tv.program', 'film.character', 'media_common.actor']
# 0, org_error: 0.3425 tran_error: 0.3075 tran_eff: 1.1138211382113823
# 1, org_error: 0.48 tran_error: 0.47 tran_eff: 1.0212765957446808
#
# 3 [16  6 17 18] ['tv.program', 'music.group', 'business.operation', 'education.field_of_study']
# 0, org_error: 0.3425 tran_error: 0.31499999999999995 tran_eff: 1.0873015873015877
# 1, org_error: 0.48 tran_error: 0.46499999999999997 tran_eff: 1.032258064516129
# 2, org_error: 0.49750000000000005 tran_error: 0.49 tran_eff: 1.0153061224489797
#
# 4 [19 15 18  1] ['education.school', 'american_football.player', 'education.field_of_study', 'book.written_work']
# 0, org_error: 0.3425 tran_error: 0.30500000000000005 tran_eff: 1.122950819672131
# 1, org_error: 0.48 tran_error: 0.4625 tran_eff: 1.0378378378378377
# 2, org_error: 0.49750000000000005 tran_error: 0.5175000000000001 tran_eff: 0.9613526570048309
# 3, org_error: 0.4225 tran_error: 0.39749999999999996 tran_eff: 1.0628930817610063
#
# 0 [11  6  4 10] ['film.actor', 'music.group', 'organization.organization', 'people.person']
#
# 1 [ 6 12 10  5] ['music.group', 'book.edition', 'people.person', 'film.film']
# 0, org_error: 0.39749999999999996 tran_error: 0.41000000000000003 tran_eff: 0.9695121951219511
#
# 2 [ 3  4  1 19] ['tv.series_episode', 'organization.organization', 'book.written_work', 'education.school']
# 0, org_error: 0.39749999999999996 tran_error: 0.385 tran_eff: 1.0324675324675323
# 1, org_error: 0.47 tran_error: 0.44499999999999995 tran_eff: 1.056179775280899
#
# 3 [ 9  0 10  4] ['music.artist', 'biology.organism_classification', 'people.person', 'organization.organization']
# 0, org_error: 0.39749999999999996 tran_error: 0.38 tran_eff: 1.0460526315789473
# 1, org_error: 0.47 tran_error: 0.44499999999999995 tran_eff: 1.056179775280899
# 2, org_error: 0.36250000000000004 tran_error: 0.3425 tran_eff: 1.0583941605839418
#
# 4 [14 11  9  7] ['book.author', 'film.actor', 'music.artist', 'commerce.consumer_product']
# 0, org_error: 0.39749999999999996 tran_error: 0.38 tran_eff: 1.0460526315789473
# 1, org_error: 0.47 tran_error: 0.4425 tran_eff: 1.0621468926553672
# 2, org_error: 0.36250000000000004 tran_error: 0.34750000000000003 tran_eff: 1.0431654676258992
# 3, org_error: 0.31000000000000005 tran_error: 0.32999999999999996 tran_eff: 0.9393939393939397
#
# 0 [ 0 12  9  2] ['biology.organism_classification', 'book.edition', 'music.artist', 'film.character']
#
# 1 [11 18  0 12] ['film.actor', 'education.field_of_study', 'biology.organism_classification', 'book.edition']
# 0, org_error: 0.37749999999999995 tran_error: 0.375 tran_eff: 1.0066666666666666
#
# 2 [10 16  6 13] ['people.person', 'tv.program', 'music.group', 'media_common.actor']
# 0, org_error: 0.37749999999999995 tran_error: 0.365 tran_eff: 1.0342465753424657
# 1, org_error: 0.21999999999999997 tran_error: 0.1875 tran_eff: 1.1733333333333331
#
# 3 [ 9 10 14  4] ['music.artist', 'people.person', 'book.author', 'organization.organization']
# 0, org_error: 0.37749999999999995 tran_error: 0.37250000000000005 tran_eff: 1.013422818791946
# 1, org_error: 0.21999999999999997 tran_error: 0.18000000000000005 tran_eff: 1.2222222222222217
# 2, org_error: 0.4475 tran_error: 0.44499999999999995 tran_eff: 1.00561797752809
#
# 4 [ 4  7 17  2] ['organization.organization', 'commerce.consumer_product', 'business.operation', 'film.character']
# 0, org_error: 0.37749999999999995 tran_error: 0.36 tran_eff: 1.048611111111111
# 1, org_error: 0.21999999999999997 tran_error: 0.1875 tran_eff: 1.1733333333333331
# 2, org_error: 0.4475 tran_error: 0.42500000000000004 tran_eff: 1.052941176470588
# 3, org_error: 0.52 tran_error: 0.5175000000000001 tran_eff: 1.004830917874396
#
# 0 [13 11 12 18] ['media_common.actor', 'film.actor', 'book.edition', 'education.field_of_study']
#
# 1 [ 0 12 10  4] ['biology.organism_classification', 'book.edition', 'people.person', 'organization.organization']
# 0, org_error: 0.39 tran_error: 0.36 tran_eff: 1.0833333333333335
#
# 2 [18  7 10 11] ['education.field_of_study', 'commerce.consumer_product', 'people.person', 'film.actor']
# 0, org_error: 0.39 tran_error: 0.38 tran_eff: 1.0263157894736843
# 1, org_error: 0.22750000000000004 tran_error: 0.21499999999999997 tran_eff: 1.0581395348837213
#
# 3 [ 6  3 16 13] ['music.group', 'tv.series_episode', 'tv.program', 'media_common.actor']
# 0, org_error: 0.39 tran_error: 0.38249999999999995 tran_eff: 1.019607843137255
# 1, org_error: 0.22750000000000004 tran_error: 0.21499999999999997 tran_eff: 1.0581395348837213
# 2, org_error: 0.38749999999999996 tran_error: 0.38249999999999995 tran_eff: 1.0130718954248366
#
# 4 [19  3 15 10] ['education.school', 'tv.series_episode', 'american_football.player', 'people.person']
# 0, org_error: 0.39 tran_error: 0.37 tran_eff: 1.0540540540540542
# 1, org_error: 0.22750000000000004 tran_error: 0.22250000000000003 tran_eff: 1.0224719101123596
# 2, org_error: 0.38749999999999996 tran_error: 0.405 tran_eff: 0.9567901234567899
# 3, org_error: 0.53 tran_error: 0.5075000000000001 tran_eff: 1.044334975369458
#
# 0 [ 8 16 11  3] ['book.book', 'tv.program', 'film.actor', 'tv.series_episode']
#
# 1 [ 9 12  0  5] ['music.artist', 'book.edition', 'biology.organism_classification', 'film.film']
# 0, org_error: 0.45999999999999996 tran_error: 0.43999999999999995 tran_eff: 1.0454545454545454
#
# 2 [ 2 19  0 13] ['film.character', 'education.school', 'biology.organism_classification', 'media_common.actor']
# 0, org_error: 0.45999999999999996 tran_error: 0.4275 tran_eff: 1.0760233918128654
# 1, org_error: 0.39 tran_error: 0.39249999999999996 tran_eff: 0.9936305732484078
#
# 3 [ 8  3 14 17] ['book.book', 'tv.series_episode', 'book.author', 'business.operation']
# 0, org_error: 0.45999999999999996 tran_error: 0.4375 tran_eff: 1.0514285714285714
# 1, org_error: 0.39 tran_error: 0.37749999999999995 tran_eff: 1.0331125827814571
# 2, org_error: 0.21250000000000002 tran_error: 0.20499999999999996 tran_eff: 1.0365853658536588
#
# 4 [13  9 15 17] ['media_common.actor', 'music.artist', 'american_football.player', 'business.operation']
# 0, org_error: 0.45999999999999996 tran_error: 0.4325 tran_eff: 1.0635838150289016
# 1, org_error: 0.39 tran_error: 0.385 tran_eff: 1.012987012987013
# 2, org_error: 0.21250000000000002 tran_error: 0.20750000000000002 tran_eff: 1.0240963855421688
# 3, org_error: 0.33999999999999997 tran_error: 0.3275 tran_eff: 1.0381679389312977
#
# 0 [14  5 11  1] ['book.author', 'film.film', 'film.actor', 'book.written_work']
#
# 1 [ 8 12  9  5] ['book.book', 'book.edition', 'music.artist', 'film.film']
# 0, org_error: 0.51 tran_error: 0.49 tran_eff: 1.0408163265306123
#
# 2 [ 7 17 14  6] ['commerce.consumer_product', 'business.operation', 'book.author', 'music.group']
# 0, org_error: 0.51 tran_error: 0.5025 tran_eff: 1.0149253731343284
# 1, org_error: 0.5925 tran_error: 0.575 tran_eff: 1.0304347826086957
#
# 3 [ 8 11  4  3] ['book.book', 'film.actor', 'organization.organization', 'tv.series_episode']
# 0, org_error: 0.51 tran_error: 0.47 tran_eff: 1.0851063829787235
# 1, org_error: 0.5925 tran_error: 0.5825 tran_eff: 1.017167381974249
# 2, org_error: 0.365 tran_error: 0.37749999999999995 tran_eff: 0.9668874172185432
#
# 4 [18  4 11 15] ['education.field_of_study', 'organization.organization', 'film.actor', 'american_football.player']
# 0, org_error: 0.51 tran_error: 0.48250000000000004 tran_eff: 1.0569948186528497
# 1, org_error: 0.5925 tran_error: 0.5675 tran_eff: 1.0440528634361235
# 2, org_error: 0.365 tran_error: 0.375 tran_eff: 0.9733333333333333
# 3, org_error: 0.375 tran_error: 0.35250000000000004 tran_eff: 1.0638297872340425
